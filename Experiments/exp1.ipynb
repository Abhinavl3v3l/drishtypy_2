# %%
import drishtypy.utils.get_cuda as cuda
device = cuda.get_device()
# Out:
# cuda available
# Device set to :  cuda:0

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

SEED = 1
batch_size=128

# %%
import os 
path = os.getcwd()
path  = path + '/dataset/'
print(path)
# Out:
# /home/abhinav/Drishtypy/dataset/

# %%
import drishtypy.data.returns_dataloader as dl
trainset, testset, train_loader, test_loader = dl.get_dataloader(batch_size=batch_size, num_workers=4, cuda = True,path = path)
# Out:
# ['/home/abhinav/Drishtypy', '/home/abhinav/anaconda3/lib/python38.zip', '/home/abhinav/anaconda3/lib/python3.8', '/home/abhinav/anaconda3/lib/python3.8/lib-dynload', '', '/home/abhinav/.local/lib/python3.8/site-packages', '/home/abhinav/anaconda3/lib/python3.8/site-packages', '/home/abhinav/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/home/abhinav/.ipython', '/home/abhinav/Drishtypy']
# Running over Cuda !!  True
# Files already downloaded and verified
# Files already downloaded and verified
# mean 0.49186864
# standard dev 0.24697131
# mean 0.48265335
# standard dev 0.24338901
# mean 0.44717798
# standard dev 0.26159254
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import drishtypy.viz.do_plots as plt
plt.plot_dataset_images(device, classes, train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import drishtypy.models.resnet as mod
model = mod.ResNet18()

# %%
from drishtypy.learner.learner import model_summary
model_summary(model, device, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
from tqdm import tqdm
from drishtypy.learner.learner import build_model

# %%
# build and train the model
model_name = "Model CIFAR10"
EPOCHS = 20
model =  model.to(device) # use GPU

# using L1 and L2 regularization
train_acc, train_losses, test_acc, test_losses = build_model(model, 
                                                            device, 
                                                            trainloader=train_loader, 
                                                            testloader=test_loader, 
                                                            epochs=EPOCHS,
                                                            L1_loss_flag=False,
                                                            L2_penalty_val=0.001)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.606290 Batch_id=390 Accuracy=41.54: 100%|██████████| 391/391 [00:47<00:00,  8.30it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.221759, Accuracy: 5634/10000 (56.34%)
#
# EPOCH: 1
# Loss=1.231848 Batch_id=390 Accuracy=55.88: 100%|██████████| 391/391 [00:50<00:00,  7.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.087804, Accuracy: 6156/10000 (61.56%)
#
# EPOCH: 2
# Loss=1.047599 Batch_id=390 Accuracy=62.65: 100%|██████████| 391/391 [00:49<00:00,  7.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.882858, Accuracy: 6932/10000 (69.32%)
#
# EPOCH: 3
# Loss=0.924620 Batch_id=390 Accuracy=67.34: 100%|██████████| 391/391 [00:49<00:00,  7.83it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.870510, Accuracy: 7058/10000 (70.58%)
#
# EPOCH: 4
# Loss=0.848507 Batch_id=390 Accuracy=70.21: 100%|██████████| 391/391 [00:50<00:00,  7.71it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.785412, Accuracy: 7182/10000 (71.82%)
#
# EPOCH: 5
# Loss=0.796315 Batch_id=390 Accuracy=72.30: 100%|██████████| 391/391 [00:48<00:00,  8.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.815604, Accuracy: 7350/10000 (73.50%)
#
# EPOCH: 6
# Loss=0.761090 Batch_id=390 Accuracy=73.48: 100%|██████████| 391/391 [00:49<00:00,  7.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.648646, Accuracy: 7809/10000 (78.09%)
#
# EPOCH: 7
# Loss=0.735068 Batch_id=390 Accuracy=74.65: 100%|██████████| 391/391 [00:48<00:00,  8.00it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.673692, Accuracy: 7663/10000 (76.63%)
#
# EPOCH: 8
# Loss=0.709186 Batch_id=390 Accuracy=75.39: 100%|██████████| 391/391 [00:49<00:00,  7.90it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.625859, Accuracy: 7840/10000 (78.40%)
#
# EPOCH: 9
# Loss=0.694909 Batch_id=390 Accuracy=75.81: 100%|██████████| 391/391 [00:49<00:00,  7.90it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.612118, Accuracy: 7903/10000 (79.03%)
#
# EPOCH: 10
# Loss=0.682683 Batch_id=390 Accuracy=76.45: 100%|██████████| 391/391 [00:49<00:00,  7.85it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.598675, Accuracy: 7953/10000 (79.53%)
#
# EPOCH: 11
# Loss=0.671820 Batch_id=390 Accuracy=76.65: 100%|██████████| 391/391 [00:50<00:00,  7.79it/s]
# Epoch    12: reducing learning rate of group 0 to 3.0000e-03.
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.581328, Accuracy: 8002/10000 (80.02%)
#
# EPOCH: 12
# Loss=0.481015 Batch_id=390 Accuracy=83.47: 100%|██████████| 391/391 [00:49<00:00,  7.85it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.351688, Accuracy: 8796/10000 (87.96%)
#
# EPOCH: 13
# Loss=0.413491 Batch_id=390 Accuracy=85.70: 100%|██████████| 391/391 [00:49<00:00,  7.91it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.335455, Accuracy: 8877/10000 (88.77%)
#
# EPOCH: 14
# Loss=0.386653 Batch_id=390 Accuracy=86.59: 100%|██████████| 391/391 [00:49<00:00,  7.91it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.326859, Accuracy: 8878/10000 (88.78%)
#
# EPOCH: 15
# Loss=0.360855 Batch_id=390 Accuracy=87.55: 100%|██████████| 391/391 [00:49<00:00,  7.88it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.322879, Accuracy: 8893/10000 (88.93%)
#
# EPOCH: 16
# Loss=0.347038 Batch_id=390 Accuracy=87.95: 100%|██████████| 391/391 [00:49<00:00,  7.90it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.315073, Accuracy: 8915/10000 (89.15%)
#
# EPOCH: 17
# Loss=0.328292 Batch_id=390 Accuracy=88.79: 100%|██████████| 391/391 [00:49<00:00,  7.87it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.303841, Accuracy: 8956/10000 (89.56%)
#
# EPOCH: 18
# Loss=0.313334 Batch_id=390 Accuracy=89.30: 100%|██████████| 391/391 [00:49<00:00,  7.89it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.306761, Accuracy: 8958/10000 (89.58%)
#
# EPOCH: 19
# Loss=0.306995 Batch_id=390 Accuracy=89.57: 100%|██████████| 391/391 [00:49<00:00,  7.93it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.311956, Accuracy: 8931/10000 (89.31%)
#
# EPOCH: 20
# Loss=0.292183 Batch_id=390 Accuracy=90.02: 100%|██████████| 391/391 [00:49<00:00,  7.92it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.308885, Accuracy: 8935/10000 (89.35%)
#
# EPOCH: 21
# Loss=0.288880 Batch_id=390 Accuracy=90.08: 100%|██████████| 391/391 [00:49<00:00,  7.92it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.307793, Accuracy: 8946/10000 (89.46%)
#
# EPOCH: 22
# Loss=0.276078 Batch_id=390 Accuracy=90.36: 100%|██████████| 391/391 [00:49<00:00,  7.92it/s]
# Epoch    23: reducing learning rate of group 0 to 3.0000e-04.
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.309996, Accuracy: 8957/10000 (89.57%)
#
# EPOCH: 23
# Loss=0.237667 Batch_id=390 Accuracy=92.09: 100%|██████████| 391/391 [00:49<00:00,  7.91it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.274259, Accuracy: 9063/10000 (90.63%)
#
# EPOCH: 24
# Loss=0.213082 Batch_id=390 Accuracy=92.88: 100%|██████████| 391/391 [00:50<00:00,  7.73it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.264522, Accuracy: 9079/10000 (90.79%)
#
# EPOCH: 25
# Loss=0.207727 Batch_id=390 Accuracy=93.09: 100%|██████████| 391/391 [00:49<00:00,  7.88it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.265630, Accuracy: 9097/10000 (90.97%)
#
# EPOCH: 26
# Loss=0.203796 Batch_id=390 Accuracy=93.25: 100%|██████████| 391/391 [00:49<00:00,  7.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.266018, Accuracy: 9102/10000 (91.02%)
#
# EPOCH: 27
# Loss=0.196784 Batch_id=390 Accuracy=93.49: 100%|██████████| 391/391 [00:49<00:00,  7.87it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.267866, Accuracy: 9106/10000 (91.06%)
#
# EPOCH: 28
# Loss=0.191879 Batch_id=390 Accuracy=93.74: 100%|██████████| 391/391 [00:49<00:00,  7.86it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.267257, Accuracy: 9110/10000 (91.10%)
#
# EPOCH: 29
# Loss=0.190112 Batch_id=390 Accuracy=93.68: 100%|██████████| 391/391 [00:49<00:00,  7.90it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.262351, Accuracy: 9120/10000 (91.20%)
#
# EPOCH: 30
# Loss=0.186654 Batch_id=390 Accuracy=93.83: 100%|██████████| 391/391 [00:49<00:00,  7.89it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.261960, Accuracy: 9127/10000 (91.27%)
#
# EPOCH: 31
# Loss=0.183235 Batch_id=390 Accuracy=93.93: 100%|██████████| 391/391 [00:49<00:00,  7.89it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.262168, Accuracy: 9131/10000 (91.31%)
#
# EPOCH: 32
# Loss=0.183858 Batch_id=390 Accuracy=94.00: 100%|██████████| 391/391 [00:49<00:00,  7.91it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.255673, Accuracy: 9135/10000 (91.35%)
#
# EPOCH: 33
# Loss=0.179171 Batch_id=390 Accuracy=93.99: 100%|██████████| 391/391 [00:49<00:00,  7.98it/s]
# Epoch    34: reducing learning rate of group 0 to 3.0000e-05.
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.254096, Accuracy: 9148/10000 (91.48%)
#
# EPOCH: 34
# Loss=0.173498 Batch_id=390 Accuracy=94.29: 100%|██████████| 391/391 [00:49<00:00,  7.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.258853, Accuracy: 9153/10000 (91.53%)
#
# EPOCH: 35
# Loss=0.171836 Batch_id=390 Accuracy=94.36: 100%|██████████| 391/391 [00:48<00:00,  7.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.256638, Accuracy: 9145/10000 (91.45%)
#
# EPOCH: 36
# Loss=0.171672 Batch_id=390 Accuracy=94.44: 100%|██████████| 391/391 [00:48<00:00,  7.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.257103, Accuracy: 9143/10000 (91.43%)
#
# EPOCH: 37
# Loss=0.171607 Batch_id=390 Accuracy=94.29: 100%|██████████| 391/391 [00:48<00:00,  7.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.257697, Accuracy: 9152/10000 (91.52%)
#
# EPOCH: 38
# Loss=0.168824 Batch_id=390 Accuracy=94.50: 100%|██████████| 391/391 [00:48<00:00,  8.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.254004, Accuracy: 9143/10000 (91.43%)
#
# EPOCH: 39
# Loss=0.169926 Batch_id=390 Accuracy=94.40: 100%|██████████| 391/391 [00:48<00:00,  8.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.257111, Accuracy: 9159/10000 (91.59%)
#
# EPOCH: 40
# Loss=0.172256 Batch_id=390 Accuracy=94.41: 100%|██████████| 391/391 [00:48<00:00,  8.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.257624, Accuracy: 9148/10000 (91.48%)
#
# EPOCH: 41
# Loss=0.167141 Batch_id=390 Accuracy=94.54: 100%|██████████| 391/391 [00:48<00:00,  8.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.258012, Accuracy: 9140/10000 (91.40%)
#
# EPOCH: 42
# Loss=0.170261 Batch_id=390 Accuracy=94.32: 100%|██████████| 391/391 [00:48<00:00,  8.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.255885, Accuracy: 9145/10000 (91.45%)
#
# EPOCH: 43
# Loss=0.168323 Batch_id=390 Accuracy=94.49: 100%|██████████| 391/391 [00:49<00:00,  7.93it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.254264, Accuracy: 9152/10000 (91.52%)
#
# EPOCH: 44
# Loss=0.166438 Batch_id=390 Accuracy=94.53: 100%|██████████| 391/391 [00:50<00:00,  7.76it/s]
# Epoch    45: reducing learning rate of group 0 to 3.0000e-06.
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.255476, Accuracy: 9142/10000 (91.42%)
#
# EPOCH: 45
# Loss=0.169323 Batch_id=390 Accuracy=94.45: 100%|██████████| 391/391 [00:49<00:00,  7.84it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.257234, Accuracy: 9139/10000 (91.39%)
#
# EPOCH: 46
# Loss=0.168864 Batch_id=390 Accuracy=94.54: 100%|██████████| 391/391 [00:49<00:00,  7.87it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.255358, Accuracy: 9143/10000 (91.43%)
#
# EPOCH: 47
# Loss=0.165048 Batch_id=390 Accuracy=94.61: 100%|██████████| 391/391 [00:49<00:00,  7.87it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.261350, Accuracy: 9140/10000 (91.40%)
#
# EPOCH: 48
# Loss=0.163318 Batch_id=390 Accuracy=94.65: 100%|██████████| 391/391 [00:49<00:00,  7.87it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.254980, Accuracy: 9161/10000 (91.61%)
#
# EPOCH: 49
# Loss=0.172382 Batch_id=390 Accuracy=94.38: 100%|██████████| 391/391 [00:49<00:00,  7.86it/s]
# Test set: Average loss: 0.256996, Accuracy: 9156/10000 (91.56%)

# %%
# import gradcam.gradcam_abs as gradcamAbs1
import drishtypy.viz.gradcam.gradcam_abs as gradcamAbs1
from drishtypy.data.data_utils import find_stats
means,stds = find_stats(path)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# mean 0.49186864
# standard dev 0.24697131
# mean 0.48265335
# standard dev 0.24338901
# mean 0.44717798
# standard dev 0.26159254

# %%
config = dict(model_type='resnet', arch=model, layer_name='layer4')
gcam = gradcamAbs1.GradCamAbs(device, config, means, stds)

# %%
gradcam_images, pred_results = gcam.applyOnMisclassifiedImages(dataloader=test_loader, num_of_images=25)

# %%
gcam.plot_results(gradcam_images, pred_results, classes, save_filename="gradcam_result_details")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-f47c98b3fed2> in <module>
# ----> 1 gcam.plot_results(gradcam_images, pred_results, classes, save_filename="gradcam_result_details")
#
# ~/Drishtypy/drishtypy/viz/gradcam/gradcam_abs.py in plot_results(self, images_set, predictions, classesname, save_filename)
#     124             cnt += 1
#     125
# --> 126         fig.savefig("model_log/" + save_filename + ".png")
#     127         return
#     128
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~/anaconda3/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_log/gradcam_result_details.png'
